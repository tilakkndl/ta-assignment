# %% [markdown]
# # Topic 2 :Importing Data (CSV, Excel, JSON)

# %% [markdown]
# ## TAsk 1

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./data/data1.csv")
df
df.head(5)
# Out:
#    Unnamed: 0   name  age  height
# 0           0   Jams   32     109
# 1           1   John   35     121
# 2           2   Jane   41     136
# 3           3    Bob   20     170
# 4           4  Alice   23     112

# %% [markdown]
# ## Task 2

# %%
df=pd.read_excel("./data/data4.xlsx")
df
df.head(5)
# Out:
#    Unnamed: 0   name  age  height
# 0           0   Jams   32     109
# 1           1   John   35     121
# 2           2   Jane   41     136
# 3           3    Bob   20     170
# 4           4  Alice   23     112

# %% [markdown]
# ## Task 3

# %%
df=pd.read_json("./data/data6.json")
df
df.head(3)
# Out:
#    name  age  height
# 0  Jams   32     109
# 1  John   35     121
# 2  Jane   41     136

# %% [markdown]
# ## TAsk 4

# %%
df=pd.read_csv("./data/data1.csv", usecols=["name", "age"])
df
df.head(5)
# Out:
#     name  age
# 0   Jams   32
# 1   John   35
# 2   Jane   41
# 3    Bob   20
# 4  Alice   23

# %% [markdown]
# ## Task 5

# %%
df=pd.read_csv("./data/data1.csv", usecols=["name", "age", "height"], index_col="height")
df
df.head(5)
# Out:
#          name  age
# height
# 109      Jams   32
# 121      John   35
# 136      Jane   41
# 170       Bob   20
# 112     Alice   23

# %% [markdown]
# ## Task 6

# %%
excel_file=pd.ExcelFile("./data/data5.xlsx")
excel_file
print(excel_file.sheet_names)
df=pd.read_excel("./data/data5.xlsx", sheet_name="Sheet1")
df
# Out:
# ['Sheet1']
#     name  age  height
# 0   Jams   32     109
# 1   John   35     121
# 2   Jane   41     136
# 3    Bob   20     170
# 4  Alice   23     112
# 5   Mike   47     158
# 6    Dan   23     165

# %% [markdown]
# ## Task 7

# %%
df_iterator=pd.read_csv("./data/organizations-10000.csv", chunksize=100)
type(df_iterator)
def chunk_csv(df_iterator):
    for df_chunk in df_iterator:
        print(df.head())
        yield df_chunk
chunk_gen=chunk_csv(df_iterator)
chunk_gen
next(chunk_gen)
next(chunk_gen)
# Out:
#     name  age  height
# 0   Jams   32     109
# 1   John   35     121
# 2   Jane   41     136
# 3    Bob   20     170
# 4  Alice   23     112
#     name  age  height
# 0   Jams   32     109
# 1   John   35     121
# 2   Jane   41     136
# 3    Bob   20     170
# 4  Alice   23     112
#      Index  Organization Id                      Name  \
# 100    101  86ea58625dCe645            Douglas-Arnold
# 101    102  b983aCf8878Cba5           Wolfe-Whitehead
# 102    103  650A10df4Eb8A3C                 Russo PLC
# 103    104  cdAaC1adDa67fce               Kaiser-Long
# 104    105  A8F647a5Bb86598  Malone, David and Santos
# ..     ...              ...                       ...
# 195    196  DCcECead25601f1               Bolton-Love
# 196    197  Fb2B2f1c8c383Be              Cross-Ortega
# 197    198  A1d88Fe6eb3eeeC    Howe, Mejia and Harper
# 198    199  bf54Bf3bA0F93Ea   Wall, Maxwell and Salas
# 199    200  c070d9E5A30BdFE             Stevens Group
#
# ...

# %% [markdown]
# ## Task 8

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Marks': [85, 90]
})
df1
df1.to_csv("csv_withou_index_column.csv", index=False, header=False)

# %% [markdown]
# ## Task 9

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Marks': [85, 90]
})

df2 = pd.DataFrame({
    'Product': ['Book', 'Pen'],
    'Price': [120, 10]
})

with pd.ExcelWriter("multiple_sheet.xlsx") as f:
    df1.to_excel(f, sheet_name="sheet1", index=False)
    df2.to_excel(f, sheet_name="sheet2", index=False)


df=pd.read_excel("multiple_sheet.xlsx", sheet_name=["sheet1", "sheet2"])
df
# Out:
# {'sheet1':     Name  Marks
#  0  Alice     85
#  1    Bob     90,
#  'sheet2':   Product  Price
#  0    Book    120
#  1     Pen     10}

# %% [markdown]
# ## Task 10

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Marks': [85, 90]
})
df1.to_json("json_file.json")

# %% [markdown]
# ## Task 11

# %%
df = pd.DataFrame({
    'Name': ['Renée', 'José', 'Zoë'],
    'City': ['München', 'São Paulo', 'Kraków'],
    'Comment': ['Café au lait', 'Déjà vu', 'Coöperate']
})
df.to_csv("./data/special_char.csv", encoding="cp1252")
try:
    # reading the file
    # df_broken=pd.read_csv("./data/special_char.csv", encoding="utf-8")
    df_broken=pd.read_csv("./data/special_char.csv", encoding="cp1252")
    print(df_broken)

except UnicodeDecodeError as e:
    print(e)
    print("Error aaxa hai")
# Out:
#    Unnamed: 0   Name       City       Comment
# 0           0  Renée    München  Café au lait
# 1           1   José  São Paulo       Déjà vu
# 2           2    Zoë     Kraków     Coöperate

# %% [markdown]
# ## Task 12

# %%
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv" 
df=pd.read_csv(url)
df
# Out:
#      Index   Height(Inches)"   "Weight(Pounds)"
# 0        1             65.78             112.99
# 1        2             71.52             136.49
# 2        3             69.40             153.03
# 3        4             68.22             142.34
# 4        5             67.79             144.30
# ..     ...               ...                ...
# 195    196             65.80             120.84
# 196    197             66.11             115.78
# 197    198             68.24             128.30
# 198    199             68.02             127.47
# 199    200             71.39             127.88
#
# [200 rows x 3 columns]

# %%
df.describe()
# Out:
#             Index   Height(Inches)"   "Weight(Pounds)"
# count  200.000000        200.000000         200.000000
# mean   100.500000         67.949800         127.221950
# std     57.879185          1.940363          11.960959
# min      1.000000         63.430000          97.900000
# 25%     50.750000         66.522500         119.895000
# 50%    100.500000         67.935000         127.875000
# 75%    150.250000         69.202500         136.097500
# max    200.000000         73.900000         158.960000

# %% [markdown]
# ## Task 13

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': ['25', 'N/A', '30', 'None', '22'],
    'Score': ['85', '90', '?', '88', '-']
}

df=pd.DataFrame(data)
df
df_cleaned=df.replace(["?", "N/A", "None", "-"], np.nan)
df_cleaned
# Out:
#       Name  Age Score
# 0    Alice   25    85
# 1      Bob  NaN    90
# 2  Charlie   30   NaN
# 3    David  NaN    88
# 4      Eva   22   NaN

# %% [markdown]
# ## Task 14

# %%
df=pd.read_csv("./data/data1.csv")
df=df.rename(columns={
    "Unnamed: 0": "RollNo"
})
df.to_csv("./data/data1_renamed.csv")
